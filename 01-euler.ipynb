# %%
# !pip install numpy pandas matplotlib scipy
# Out:
# ...
#   Using cached numpy-2.1.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.54.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (163 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# $y'(t) = f(t, y)$
# <br>
# $𝑦(𝑡 + \delta t) = 𝑦(𝑡) + \delta t f(y(t))$

# %% [markdown]
# 1a) Write a Python script that implements the Euler method and solve the differential
# equation:
#
# $\frac{dy}{dt} = y$

# %%
interval = 0.001

ts = np.arange(0, 10, interval)
ys = [1]

# %%
def f(y_at_t):
    return y_at_t

# %%
for i in range(1, len(ts)):
    t = ts[i]
    prev_y = ys[i-1]
    new_val = prev_y + (interval * f(prev_y))
    ys.append(new_val)

# %%
def exp(t):
    return np.exp(t)

# %%
plt.title("Euler method")
plt.plot(ts, ys)
plt.plot(ts, exp(ts))
plt.show()

# %% [markdown]
# 1b) <br>
# $my''(t) = −cy'(t) - ky(t)$
# <br>
# $p(t) = y'(t)$
# <br>
# <br>
# $my''(t) = -cp(t) - ky(t)$

# %% [markdown]
# $𝑦'(𝑡 + \delta t) = 𝑦'(𝑡) + \delta t y''(t)$

# %%
ps = [0]
ys = [1]
ts = np.arange(0, 100, interval)

m = 1
c = 0.1
k = 1

# %%
for i in range(1, len(ts)):
    y_prime_t = ps[i-1]
    y_t = ys[i-1]
    y_prime_prime_t = -(((c/m) * (y_prime_t)) + ((k/m) * y_t))
    y_prime_new = y_prime_t + (interval * y_prime_prime_t)
    y_new = y_t + (interval * y_prime_t)
    ps.append(y_prime_new)
    ys.append(y_new)

# %%
plt.plot(ts, ys)

# %% [markdown]
# 1c) Range-Kutta method

# %%
ps = [0]
ys = [1]
ts = np.arange(0, 100, interval)

m = 1
c = 0.1
k = 1

# %%
for i in range(1, len(ts)):
    y_prime_t = ps[i-1]
    y_t = ys[i-1]
    y_prime_prime_t = -(((c/m) * (y_prime_t)) + ((k/m) * y_t))
    y_prime_new = y_prime_t + (interval * y_prime_prime_t)
    y_new = y_t + (interval * y_prime_t)
    ps.append(y_prime_new)
    ys.append(y_new)
